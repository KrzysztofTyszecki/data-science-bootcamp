# %% [markdown]
# <a href="https://colab.research.google.com/github/KrzysztofTyszecki/data-science-bootcamp/blob/main/Data_Vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
fig.show
# Out:
# <bound method Figure.show of <Figure size 640x480 with 0 Axes>>

# %%
plt.plot([0, 1], [0, 3])

# %%
import seaborn as sns
sns.set()

# %%
plt.plot([0, 1], [0, 3], label='awesome_green_line', color='green')
plt.legend()
plt.xlabel('X axe')
plt.ylabel('Y axe')
plt.title('Awesome Line')
# Out:
# Text(0.5, 1.0, 'Awesome Line')

# %%
x = np.arange(-3, 3, 0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)

# %%
plt.plot(x, x_sin, label='sinus')
plt.plot(x, x_cos, label='cosinus')
plt.legend()

# %%
fig=plt.figure(figsize=(10, 6))
plt.subplot(131)
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(132)
plt.plot([0, 1, 2], [1, 3, 4], color='red')
plt.subplot(133)
plt.plot([0, 1, 2], [5, 2, 0],'r--')

# %%
plt.bar(x=[0, 1, 2, 3], height=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
x1 = np.random.randn(100)
x2 = np.random.randn(100)

plt.scatter(x=x1, y=x2)

# %%
x3 = np.random.randn(100) * 50

plt.scatter(x=x1, y=x2, s=x3, alpha=0.6)
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# IMAGE

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('office.jpg')
img
# Out:
# array([[[117,  98,  56],
#         [117,  98,  56],
#         [116,  97,  55],
#         ...,
#         [ 98,  82,  48],
#         [ 98,  82,  48],
#         [ 95,  79,  45]],
#
#        [[118,  99,  57],
#         [120, 101,  59],
#         [121, 102,  60],
#         ...,
#         [101,  85,  51],
#         [101,  85,  51],
#         [ 97,  81,  47]],
#
#        [[116,  97,  55],
#         [118,  99,  57],
#         [120, 101,  59],
#         ...,
#         [108,  92,  58],
#         [104,  88,  54],
#         [100,  84,  50]],
#
#        ...,
#
#        [[ 84,  65,  22],
#         [ 86,  67,  24],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  35,   1],
#         [ 58,  35,   1],
#         [ 58,  35,   1]],
#
#        [[ 86,  67,  24],
#         [ 87,  68,  25],
#         [ 89,  70,  28],
#         ...,
#         [ 58,  33,   2],
#         [ 58,  33,   2],
#         [ 57,  32,   1]],
#
#        [[ 88,  69,  26],
#         [ 90,  71,  28],
#         [ 91,  72,  30],
# ...

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1360763574.py in <cell line: 0>()
# ----> 1 plt.imshow(img)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     216         if name in props:
#     217             return props[name].__get__(instance)
# --> 218         raise AttributeError(
#     219             f"module {cls.__module__!r} has no attribute {name!r}")
#     220
#
# AttributeError: module 'matplotlib' has no attribute 'imshow'

# %%
plt.imshow(img)

# %%
fig = plt.figure(figsize=(12, 10))
plt.subplot(221)
plt.imshow(mpimg.imread('office.jpg'))
plt.subplot(222)
plt.imshow(mpimg.imread('business.jpg'))
plt.subplot(223)
plt.imshow(mpimg.imread('children.jpg'))
plt.subplot(224)
plt.imshow(mpimg.imread('workplace.jpg'))

# %%
fig = plt.figure(figsize=(12, 10))

for idx, img in enumerate(['office.jpg', 'business.jpg', 'children.jpg', 'workplace.jpg']):
    plt.subplot(220 + idx + 1)
    plt.imshow(mpimg.imread(img))

# %%
for idx, img in enumerate(['office.jpg', 'business.jpg', 'children.jpg', 'workplace.jpg']):
    plt.subplot(140 + idx + 1)
    plt.imshow(mpimg.imread(img))

# %% [markdown]
# MATPLOTLIB STYLE
