# %% [markdown]
# <a href="https://colab.research.google.com/github/KrzysztofTyszecki/data-science-bootcamp/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s = pd.Series([2,5,7])
s
# Out:
# 0    2
# 1    5
# 2    7
# dtype: int64

# %%
import numpy as np

# %%
s = pd.Series([2, np.nan, 5,7])
s
# Out:
# 0    2.0
# 1    NaN
# 2    5.0
# 3    7.0
# dtype: float64

# %%
s = pd.Series(data=np.arange(10,20), index=pd.date_range(start='20220101', periods=10))
s
# Out:
# 2022-01-01    10
# 2022-01-02    11
# 2022-01-03    12
# 2022-01-04    13
# 2022-01-05    14
# 2022-01-06    15
# 2022-01-07    16
# 2022-01-08    17
# 2022-01-09    18
# 2022-01-10    19
# Freq: D, dtype: int64

# %%
list(s.index)
# Out:
# [Timestamp('2022-01-01 00:00:00'),
#  Timestamp('2022-01-02 00:00:00'),
#  Timestamp('2022-01-03 00:00:00'),
#  Timestamp('2022-01-04 00:00:00'),
#  Timestamp('2022-01-05 00:00:00'),
#  Timestamp('2022-01-06 00:00:00'),
#  Timestamp('2022-01-07 00:00:00'),
#  Timestamp('2022-01-08 00:00:00'),
#  Timestamp('2022-01-09 00:00:00'),
#  Timestamp('2022-01-10 00:00:00')]

# %%
s.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
price = pd.Series(data={"Apple":200, "CD Projekt":60, "Amazon":500, "KGHM":np.nan})
price
# Out:
# Apple         200.0
# CD Projekt     60.0
# Amazon        500.0
# KGHM            NaN
# dtype: float64

# %%
price['CD Projekt']
# Out:
# np.float64(60.0)

# %%
price[1]
# Out:
# /tmp/ipython-input-4074423798.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   price[1]
# np.float64(60.0)

# %%
price.value_counts()
# Out:
# 200.0    1
# 60.0     1
# 500.0    1
# Name: count, dtype: int64

# %%
price.min()
# Out:
# 60.0

# %%
price.std()
# Out:
# 224.79620400116485

# %%
price.describe()
# Out:
# count      3.000000
# mean     253.333333
# std      224.796204
# min       60.000000
# 25%      130.000000
# 50%      200.000000
# 75%      350.000000
# max      500.000000
# dtype: float64

# %%
price_pln = price.apply(lambda x: x * 3.8)
price_pln
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
df = pd.DataFrame(data=[12,12,32], index=['first', 'second', 'third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df1 = pd.DataFrame(data={'WIG20': ['PKN ORLEN', 'PKO BP'],
                        'mWIG40': ['Amica', 'Playway']})
df1
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df1.describe().T
# Out:
#        count unique        top freq
# WIG20      2      2  PKN ORLEN    1
# mWIG40     2      2      Amica    1

# %%
df = pd.DataFrame(data=[[10, 12, 13], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
df.columns=['a', 'b', 'c']
df
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
df.a
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
df['d']=df.a + df.c
df
# Out:
#          a   b   c   d
# first   10  12  13  23
# second  23  12  10  33

# %%
df.loc['first', 'c']
# Out:
# np.int64(13)
